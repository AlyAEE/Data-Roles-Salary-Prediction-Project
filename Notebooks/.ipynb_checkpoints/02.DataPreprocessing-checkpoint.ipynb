# %%
DATA_PATH = '../Data/Raw/'
PKL_EXPORT_PATH = "../data/processed/0_DataCleaned_all_df.pkl"
CSV_EXPORT_PATH = "../data/processed/0_DataCleaned_all_df.csv"
US_STATES_ABBR = '../Data/Raw/us_states.xlsx'

# %%
# Packages to import
import pandas as pd 
import numpy as np
import re
import logging
import pickle
import glob
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Get CSV files list from a folder
csv_files = glob.glob(DATA_PATH + "/raw_*")
# load the dataframes and concatenate them
raw_df = pd.concat(map(pd.read_csv, csv_files))
raw_df = raw_df.set_index('Unnamed: 0').reset_index(drop=True)
raw_df.shape
# Out:
# (8000, 12)

# %%
raw_df
# Out:
#                                               Job Title  \
# 0                                          Data Analyst
# 1                                          Data Analyst
# 2                                          Data Analyst
# 3                                   Data Mining Analyst
# 4                                          Data Analyst
# ...                                                 ...
# 7995                       Machine Learning Scientist I
# 7996  Data Scientist(RNAseq,Genomics,Omnics,Machine ...
# 7997  Machine Learning Research Scientist - Natural ...
# 7998              Sr Applied Machine Learning Scientist
# 7999  Machine Learning Data Scientist - Inventory Al...
#
#                                         Salary Estimate  \
# 0                Employer Provided Salary:$102K - $148K
# 1                                                    -1
# 2                          $54K - $82K (Glassdoor est.)
# 3                          $63K - $91K (Glassdoor est.)
# 4     Employer Provided Salary:$40.00 - $45.00 Per Hour
# ...                                                 ...
# 7995                      $95K - $136K (Glassdoor est.)
# 7996  Employer Provided Salary:$51.00 - $52.00 Per Hour
# 7997             Employer Provided Salary:$152K - $210K
# 7998             Employer Provided Salary:$128K - $196K
# 7999             Employer Provided Salary:$160K - $226K
#
#                                         Job Description  Rating  \
# 0     At Realtor.com®, we have among the most compre...     3.7
# 1     Greetings\nI am seeking for technical consulta...    -1.0
# 2     This is an in-office position, working out of ...     4.5
# 3     Kodak Alaris is a global technology company th...     4.0
# 4     Primary Duties: Data Analyst 2\nProvide ad-hoc...     3.9
# ...                                                 ...     ...
# 7995  Machine Learning Scientist I\nFlexible within ...     3.5
# 7996  Job Description:\nResponsibilities:\nProject i...     3.7
# 7997  At Toyota Research Institute (TRI), we’re on a...     4.1
# 7998  About Grainger\nGrainger is a global leading b...     4.1
# 7999  We’re a team of bright, kind individuals who a...     3.2
#
#                         Company Name         Location  \
# 0           Realtor.com Careers\n3.7       Austin, TX
# 1                       SMK Soft Inc           Remote
# 2               Visionary Homes\n4.5  North Logan, UT
# 3                  Kodak Alaris\n4.0    Rochester, NY
# 4             GSK Solutions Inc\n3.9     Richmond, VA
# ...                              ...              ...
# 7995    Cambia Health Solutions\n3.5     Portland, OR
# 7996           Tellus Solutions\n3.7           Remote
# 7997  Toyota Research Institute\n4.1    Los Altos, CA
# 7998                   Grainger\n4.1      Chicago, IL
# 7999                 Stitch Fix\n3.2           Remote
#
#                          Size  Founded               Type of ownership  \
# 0      1001 to 5000 Employees     1993               Company - Private
# 1                          -1       -1                              -1
# 2         51 to 200 Employees     2004               Company - Private
# 3      1001 to 5000 Employees     2013               Company - Private
# 4           1 to 50 Employees     2010               Company - Private
# ...                       ...      ...                             ...
# 7995  5001 to 10000 Employees     1917          Nonprofit Organization
# 7996      51 to 200 Employees     2006               Company - Private
# 7997     201 to 500 Employees     2016  Subsidiary or Business Segment
# 7998         10000+ Employees     1927                Company - Public
# 7999         10000+ Employees     2011                Company - Public
#
#                                      Industry  \
# 0               Computer Hardware Development
# 1                                          -1
# 2                                Construction
# 3     Information Technology Support Services
# 4                         Business Consulting
# ...                                       ...
# 7995         Health Care Services & Hospitals
# 7996  Information Technology Support Services
# 7997                   Research & Development
# 7998                                Wholesale
# 7999                      Other Retail Stores
#
#                                            Sector  \
# 0                          Information Technology
# 1                                              -1
# 2     Construction, Repair & Maintenance Services
# 3                          Information Technology
# 4                         Management & Consulting
# ...                                           ...
# 7995                                   Healthcare
# 7996                       Information Technology
# 7997                      Management & Consulting
# 7998                           Retail & Wholesale
# 7999                           Retail & Wholesale
#
#                                Revenue
# 0             Unknown / Non-Applicable
# 1                                   -1
# 2             Unknown / Non-Applicable
# 3     $500 million to $1 billion (USD)
# 4              $5 to $25 million (USD)
# ...                                ...
# 7995          Unknown / Non-Applicable
# 7996           $5 to $25 million (USD)
# 7997          Unknown / Non-Applicable
# 7998                $10+ billion (USD)
# 7999            $1 to $5 billion (USD)
#
# [8000 rows x 12 columns]

# %%
# Display random answer
raw_df.sample(1).iloc[0]
# Out:
# Job Title                                        Data Engineer - LATAM
# Salary Estimate                                                     -1
# Job Description      About Passport:\n\nPassport is reinventing cro...
# Rating                                                             2.7
# Company Name                                             Passport\n2.7
# Location                                                        Remote
# Size                                              201 to 500 Employees
# Founded                                                           2010
# Type of ownership                                    Company - Private
# Industry                                 Computer Hardware Development
# Sector                                          Information Technology
# Revenue                                        $5 to $25 million (USD)
# Name: 3399, dtype: object

# %%
raw_df.sample()
# Out:
#          Job Title               Salary Estimate  \
# 1028  Data Analyst  $59K - $86K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 1028  Data Analyst\nLocation: Atlanta, GA, 30328\nWe...    -1.0
#
#                Company Name     Location               Size  Founded  \
# 1028  Healthlink Dimensions  Atlanta, GA  1 to 50 Employees     2001
#
#       Type of ownership Industry Sector                  Revenue
# 1028  Company - Private       -1     -1  $5 to $25 million (USD)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          8000 non-null   object
#  1   Salary Estimate    8000 non-null   object
#  2   Job Description    8000 non-null   object
#  3   Rating             8000 non-null   float64
#  4   Company Name       8000 non-null   object
#  5   Location           7998 non-null   object
#  6   Size               8000 non-null   object
#  7   Founded            8000 non-null   int64
#  8   Type of ownership  8000 non-null   object
#  9   Industry           8000 non-null   object
#  10  Sector             8000 non-null   object
#  11  Revenue            8000 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 750.1+ KB

# %% [markdown]
# # Data Cleaning & preprocessing
# __________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Salary Column

# %% [markdown]
# ### 1. Parse the Salary Data Column
# ### 2. Remove rows in which salary equal -1
# ### 3. Remove any Text in the columns
# ### 4. Change Hourly Rate salary to Yearly rate
# ### 5. split salary into min and max salary column
# ### 6. calculate the avg salary

# %%
# How many Null values in the salary column
len(raw_df[raw_df['Salary Estimate' ] == '-1'])
# Out:
# 2010

# %%
# Remove Columns where Salary == -1, We Ended up with 778 rows that have salary
raw_df = raw_df[raw_df['Salary Estimate'] != '-1']
len(raw_df)
# Out:
# 5990

# %%
raw_df['Salary Estimate'].sample(20)
# Out:
# 4111                Employer Provided Salary:$93K - $103K
# 2013               Employer Provided Salary:$134K - $194K
# 5285                Employer Provided Salary:$89K - $120K
# 2590                        $76K - $108K (Glassdoor est.)
# 3414               Employer Provided Salary:$150K - $175K
# 1415                 Employer Provided Salary:$65K - $80K
# 4281               Employer Provided Salary:$140K - $178K
# 2963                        $89K - $128K (Glassdoor est.)
# 2717                       $107K - $149K (Glassdoor est.)
# 5240                        $95K - $136K (Glassdoor est.)
# 3904               Employer Provided Salary:$110K - $196K
# 2108               Employer Provided Salary:$134K - $194K
# 2602                        $70K - $106K (Glassdoor est.)
# 325     Employer Provided Salary:$30.00 - $35.00 Per Hour
# 3220                        $89K - $128K (Glassdoor est.)
# 1871                        $71K - $101K (Glassdoor est.)
# 809                          $50K - $70K (Glassdoor est.)
# 2143    Employer Provided Salary:$60.00 - $70.00 Per Hour
# 5133                Employer Provided Salary:$97K - $234K
# 4257                        $95K - $136K (Glassdoor est.)
# Name: Salary Estimate, dtype: object

# %%
# Use Regex to Remove Text in the Salary Column
salary = raw_df['Salary Estimate'].str.replace(r'[^0-9-_]', '',regex = True)
salary.sample(10)
# Out:
# 3863      160-247
# 254         64-85
# 5592      126-222
# 102       130-196
# 2173    6000-8000
# 671            53
# 4921      140-178
# 1077        65-80
# 24          75-90
# 625       102-148
# Name: Salary Estimate, dtype: object

# %%
# The Per hour Columns salary became so big after the dot removed
print(salary.loc[325])
print(salary.loc[2143])
print(salary.loc[15])
# Out:
# 3000-3500
# 6000-7000
# 2475-2850

# %%
# split the salary column into a list 
list_salary =salary.str.split('-')

# %%
# We need to change the per hour salary to per year
# per year rate = no. * 1.8 / 1000
#Loop through the salary list and check for numbers > 1000 (per hour columns) and divide by 100
for s in list_salary:
    for i in range(len(s)):
        if int(s[i]) >= 1000:
            s[i] = (int(s[i]) * 1.8)/ 100

# %%
print(list_salary.loc[2143])
print(list_salary.loc[325])
print(list_salary.loc[15])
# Out:
# [108.0, 126.0]
# [54.0, 63.0]
# [44.55, 51.3]

# %%
raw_df = raw_df.copy()
# Create Two new columns( one for min_salary and one for max_salary)
raw_df['min_salary'] = list_salary.apply(lambda x: int(x[0]))
# Takes x[0] if list has only one value,
raw_df['max_salary'] = list_salary.apply(lambda x: int(x[1]) if len(x)>1 else int(x[0]))

# %%
list_salary
# Out:
# 0           [54, 82]
# 1           [63, 91]
# 2       [72.0, 81.0]
# 3           [65, 85]
# 4               [99]
#             ...
# 5658       [95, 136]
# 5659    [91.8, 93.6]
# 5660      [152, 210]
# 5661      [128, 196]
# 5662      [160, 226]
# Name: Salary Estimate, Length: 5663, dtype: object

# %%
pd.reset_option('mode.chained_assignment')
with pd.option_context('mode.chained_assignment', None):# Evaluate the avg salary
    raw_df['avg_salary'] = (raw_df.min_salary + raw_df.max_salary) / 2

# %%
raw_df
# Out:
#                                               Job Title  \
# 0                                          Data Analyst
# 2                                          Data Analyst
# 3                                   Data Mining Analyst
# 4                                          Data Analyst
# 5                                          Data Analyst
# ...                                                 ...
# 7995                       Machine Learning Scientist I
# 7996  Data Scientist(RNAseq,Genomics,Omnics,Machine ...
# 7997  Machine Learning Research Scientist - Natural ...
# 7998              Sr Applied Machine Learning Scientist
# 7999  Machine Learning Data Scientist - Inventory Al...
#
#                                         Salary Estimate  \
# 0                Employer Provided Salary:$102K - $148K
# 2                          $54K - $82K (Glassdoor est.)
# 3                          $63K - $91K (Glassdoor est.)
# 4     Employer Provided Salary:$40.00 - $45.00 Per Hour
# 5                  Employer Provided Salary:$65K - $85K
# ...                                                 ...
# 7995                      $95K - $136K (Glassdoor est.)
# 7996  Employer Provided Salary:$51.00 - $52.00 Per Hour
# 7997             Employer Provided Salary:$152K - $210K
# 7998             Employer Provided Salary:$128K - $196K
# 7999             Employer Provided Salary:$160K - $226K
#
#                                         Job Description  Rating  \
# 0     At Realtor.com®, we have among the most compre...     3.7
# 2     This is an in-office position, working out of ...     4.5
# 3     Kodak Alaris is a global technology company th...     4.0
# 4     Primary Duties: Data Analyst 2\nProvide ad-hoc...     3.9
# 5      Responsible for the design, development and ...     2.0
# ...                                                 ...     ...
# 7995  Machine Learning Scientist I\nFlexible within ...     3.5
# 7996  Job Description:\nResponsibilities:\nProject i...     3.7
# 7997  At Toyota Research Institute (TRI), we’re on a...     4.1
# 7998  About Grainger\nGrainger is a global leading b...     4.1
# 7999  We’re a team of bright, kind individuals who a...     3.2
#
#                         Company Name         Location  \
# 0           Realtor.com Careers\n3.7       Austin, TX
# 2               Visionary Homes\n4.5  North Logan, UT
# 3                  Kodak Alaris\n4.0    Rochester, NY
# 4             GSK Solutions Inc\n3.9     Richmond, VA
# 5        Cognize Tech Solutions\n2.0           Remote
# ...                              ...              ...
# 7995    Cambia Health Solutions\n3.5     Portland, OR
# 7996           Tellus Solutions\n3.7           Remote
# 7997  Toyota Research Institute\n4.1    Los Altos, CA
# 7998                   Grainger\n4.1      Chicago, IL
# 7999                 Stitch Fix\n3.2           Remote
#
#                          Size  Founded               Type of ownership  \
# 0      1001 to 5000 Employees     1993               Company - Private
# 2         51 to 200 Employees     2004               Company - Private
# 3      1001 to 5000 Employees     2013               Company - Private
# 4           1 to 50 Employees     2010               Company - Private
# 5         51 to 200 Employees       -1               Company - Private
# ...                       ...      ...                             ...
# 7995  5001 to 10000 Employees     1917          Nonprofit Organization
# 7996      51 to 200 Employees     2006               Company - Private
# 7997     201 to 500 Employees     2016  Subsidiary or Business Segment
# 7998         10000+ Employees     1927                Company - Public
# 7999         10000+ Employees     2011                Company - Public
#
#                                      Industry  \
# 0               Computer Hardware Development
# 2                                Construction
# 3     Information Technology Support Services
# 4                         Business Consulting
# 5                                          -1
# ...                                       ...
# 7995         Health Care Services & Hospitals
# 7996  Information Technology Support Services
# 7997                   Research & Development
# 7998                                Wholesale
# 7999                      Other Retail Stores
#
#                                            Sector  \
# 0                          Information Technology
# 2     Construction, Repair & Maintenance Services
# 3                          Information Technology
# 4                         Management & Consulting
# 5                                              -1
# ...                                           ...
# 7995                                   Healthcare
# 7996                       Information Technology
# 7997                      Management & Consulting
# 7998                           Retail & Wholesale
# 7999                           Retail & Wholesale
#
#                                Revenue  min_salary  max_salary  avg_salary
# 0             Unknown / Non-Applicable         102         148       125.0
# 2             Unknown / Non-Applicable          54          82        68.0
# 3     $500 million to $1 billion (USD)          63          91        77.0
# 4              $5 to $25 million (USD)          72          81        76.5
# 5             Unknown / Non-Applicable          65          85        75.0
# ...                                ...         ...         ...         ...
# 7995          Unknown / Non-Applicable          95         136       115.5
# 7996           $5 to $25 million (USD)          91          93        92.0
# 7997          Unknown / Non-Applicable         152         210       181.0
# 7998                $10+ billion (USD)         128         196       162.0
# 7999            $1 to $5 billion (USD)         160         226       193.0
#
# [5990 rows x 15 columns]

# %% [markdown]
# ## 1. Job title Column

# %% [markdown]
# ### 1. Try to classify the job titles in terms of title and seniority
# ### 2. the seniority column has alot of missing values

# %%
raw_df['Job Title'].value_counts().head(60)
# Out:
# Data Analyst                                                              609
# Data Engineer                                                             445
# Data Scientist                                                            439
# Machine Learning Engineer                                                 212
# Decision Scientist                                                        146
# Senior Data Engineer                                                      113
# Senior Data Scientist                                                      82
# Staff Data Scientist                                                       79
# Junior Data Engineer                                                       75
# Data Analytics Engineer                                                    65
# Machine Learning Engineer II                                               56
# Associate Data & Decision Scientist                                        52
# Data Analyst I                                                             51
# Artificial Intelligence (AI) Trainer                                       49
# Clinicial Data Analyst                                                     46
# Research Scientist: Machine Learning & AI (Remote/Part-time)               45
# Applied Scientist - Machine Learning                                       44
# Data Scientist, Product Engagement                                         39
# College Graduate - Data Science (BS/MS)                                    37
# Machine Learning Scientist I                                               35
# Software Engineer 1 - Machine Learning                                     35
# Data Scientist(RNAseq,Genomics,Omnics,Machine Learning,data analysis)      34
# Applied Machine Learning Scientist - Globalization                         34
# Lead Analyst, Data (REMOTE)                                                33
# Staff Data Analyst                                                         33
# Data Scientist I                                                           33
# Jr. Data Scientist, Minerva Analytics                                      32
# Aspire Tech Program - Data Scientist I                                     32
# Data Engineer II                                                           31
# Data Scientist III (Data Products)                                         31
# Data Scientist - Machine Learning - Genome Modeling                        31
# BI Data Engineer II                                                        30
# Data Analyst 1                                                             30
# Sr. Data Engineer                                                          30
# Data Partnerships Lead                                                     30
# Data Analyst/Power BI (Remote)                                             30
# Operational Data Analyst                                                   29
# Machine Learning Scientist, Responsible AI - Large Language Model          29
# Senior Data Scientist, Ops Data Platform                                   29
# Jr Data Scientist                                                          29
# Staff Applied Research Scientist                                           29
# AI Machine Learning Scientist                                              29
# Machine Learning Infrastructure Engineer - (Multiple Levels)               29
# Data Engineer 2 - Data & Analytics Engineering                             29
# AI Content Writer                                                          29
# Machine Learning Engineer / Scientist                                      28
# Jr. Reporting Analyst                                                      28
# Data Analyst - REI Experiences                                             28
# SQL Data Analyst                                                           28
# Data Engineer - Remote                                                     28
# Principal Machine Learning Scientist                                       28
# Data Analyst/Power Apps Junior                                             27
# BrightDrop - Data Scientist – Delivery Intelligence Group                  27
# Junior Consultant in Strategy & Data Science - New York                    27
# Principal Machine Learning Engineers (Remote/Part-time) for Healthcare     27
# Data Scientist, People Data & Insights                                     27
# Data & Reporting Analyst                                                   27
# DATA ANALYST I                                                             26
# Senior Analyst - Data Science                                              26
# Data Scientist, RWE Clinical Trials, Remote                                26
# Name: Job Title, dtype: int64

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower() or 'data science' in title.lower():
        return 'data scientist'
    elif 'data analyst' in title.lower() or 'analyst' in title.lower():
        return 'data analyst'
    elif 'decision scientist' in title.lower():
        return 'decision scientist'
    elif 'artificial intelligence' in title.lower() or 'machine learning' in title.lower() or 'nlp engineer' in title.lower():
        return 'machine learning engineer'
    elif 'deep learning' in title.lower() or 'ml' in title.lower() or 'ai' in title.lower():
        return 'machine learning engineer'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'quantitative researcher' in title.lower():
        return 'quantitative researcher'
    elif 'data partnerships lead' in title.lower():
        return 'data partnerships lead'
    elif 'scientist' in title.lower():
        return 'data scientist'
    elif 'engineer' in title.lower():
        return'data engineer'
    else:
        return 'na'
    
def seniorty(title):
    if 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
raw_df['job_title'] = raw_df['Job Title'].apply(title_simplifier)

# %%
raw_df.job_title.value_counts()
# Out:
# data analyst                 1554
# data scientist               1541
# data engineer                1426
# machine learning engineer    1213
# decision scientist            198
# data partnerships lead         30
# na                             26
# quantitative researcher         2
# Name: job_title, dtype: int64

# %%
raw_df.loc[raw_df['job_title'] == 'na','Job Title'].value_counts()
# Out:
# Software Support Representative                  8
# Personalized Internet Assessor (US)              5
# SDE - Amazon Robotics, Robotic                   5
# Junior BA                                        1
# DevSecOps                                        1
# Small Business Loan Collector                    1
# Operations/HR Assistant                          1
# Remote Customer Service Representative           1
# Mathematician                                    1
# VP, Data Intelligence                            1
# People Service Intake and Transformation Lead    1
# Name: Job Title, dtype: int64

# %%
raw_df = raw_df.loc[raw_df['job_title'] != 'na']

# %%
raw_df= raw_df.copy()
raw_df['seniority'] = raw_df['Job Title'].apply(seniorty)

# %%
# alot of Na in the seniority column
raw_df['seniority'].value_counts()
# Out:
# na        4875
# senior     725
# junior     364
# Name: seniority, dtype: int64

# %% [markdown]
# ## 3. Description Column

# %% [markdown]
# ### 1. Create a new column call Desc_length, contain no. of characters in each job description

# %%
raw_df['Job Description'][0]
# Out:
# 'At Realtor.com®, we have among the most comprehensive and accurate coverage of real estate listings and the most engaged users across all the online real estate portals. Our mission is to make buying, selling, renting, and living in homes easier and more rewarding for everyone.\nBuilding your career? Build it better at Realtor.com®. Join us and help change the world of real estate, one home at a time.\nWe have the most comprehensive and accurate coverage of real estate listings and the most engaged users across all the online real estate portals. Our mission is to make buying, selling, renting, and living in homes more effortless and rewarding for everyone.\nThe Data Analytics team at Realtor.com sits at the heart of this mission. We process and analyze terabytes of data every day that enable decisions for millions of home buyers, sellers, renters, dreamers, and real estate professionals. Our goal is to use this data to make the home-buying experience a breeze for our consumers. We empower them with the most up-to-date information on properties, help them find their dream homes in the least amount of time, and match them with the most suitable realtor to meet their unique, individual needs.'

# %%
raw_df['desc_len'] = raw_df['Job Description'].apply(lambda x: len(x))
raw_df['desc_len']
# Out:
# 0       1206
# 2        914
# 3       2071
# 4        593
# 5        901
#         ...
# 7995    7095
# 7996     882
# 7997    4785
# 7998    4682
# 7999    8576
# Name: desc_len, Length: 5964, dtype: int64

# %%
raw_df['desc_len'].hist()
# Out:
# <Axes: >

# %%
words = " ".join(raw_df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
words_count= {}
for word in words_filtered:
    words_count[word] = words_count.get(word,0) +1
tools = ['python', 'r', 'aws', 'azure','hadoop','spark','excel''statistics','sql', 'azure','tensor','pytorch','keras', 'scikit-learn']
techs = ['nlp','llm','visualization','mining','cloud','ml','ai','machine', 'deep','chatgpt','neural','etl','warehousing','insights','research']
education =['phd','doctorate','master','msc','bsc','bachelor']
for tool in tools:
    if tool in words_count:
        print(f'{tool} : {words_count[tool]}')
# Out:
# python : 3093
# r : 1322
# aws : 1395
# azure : 969
# hadoop : 378
# spark : 494
# sql : 3358
# azure : 969
# pytorch : 340
# keras : 267

# %%
count = []
for row in range(len(raw_df)):
    sum = 0
    for tool in tools:
        if tool in raw_df.iloc[row,2]:
            sum +=1
    count.append(sum)
raw_df['tools'] = count

# %%
count = []
for row in range(len(raw_df)):
    sum = 0
    for tech in techs:
        if tool in raw_df.iloc[row,2]:
            sum +=1
    count.append(sum)
raw_df['techs'] = count

# %%
count = []
for row in range(len(raw_df)):
    sum = 0
    for edu in education:
        if tool in raw_df.iloc[row,2]:
            sum +=1
    count.append(sum)
raw_df['education'] = count

# %%
raw_df
# Out:
#                                               Job Title  \
# 0                                          Data Analyst
# 2                                          Data Analyst
# 3                                   Data Mining Analyst
# 4                                          Data Analyst
# 5                                          Data Analyst
# ...                                                 ...
# 7995                       Machine Learning Scientist I
# 7996  Data Scientist(RNAseq,Genomics,Omnics,Machine ...
# 7997  Machine Learning Research Scientist - Natural ...
# 7998              Sr Applied Machine Learning Scientist
# 7999  Machine Learning Data Scientist - Inventory Al...
#
#                                         Salary Estimate  \
# 0                Employer Provided Salary:$102K - $148K
# 2                          $54K - $82K (Glassdoor est.)
# 3                          $63K - $91K (Glassdoor est.)
# 4     Employer Provided Salary:$40.00 - $45.00 Per Hour
# 5                  Employer Provided Salary:$65K - $85K
# ...                                                 ...
# 7995                      $95K - $136K (Glassdoor est.)
# 7996  Employer Provided Salary:$51.00 - $52.00 Per Hour
# 7997             Employer Provided Salary:$152K - $210K
# 7998             Employer Provided Salary:$128K - $196K
# 7999             Employer Provided Salary:$160K - $226K
#
#                                         Job Description  Rating  \
# 0     At Realtor.com®, we have among the most compre...     3.7
# 2     This is an in-office position, working out of ...     4.5
# 3     Kodak Alaris is a global technology company th...     4.0
# 4     Primary Duties: Data Analyst 2\nProvide ad-hoc...     3.9
# 5      Responsible for the design, development and ...     2.0
# ...                                                 ...     ...
# 7995  Machine Learning Scientist I\nFlexible within ...     3.5
# 7996  Job Description:\nResponsibilities:\nProject i...     3.7
# 7997  At Toyota Research Institute (TRI), we’re on a...     4.1
# 7998  About Grainger\nGrainger is a global leading b...     4.1
# 7999  We’re a team of bright, kind individuals who a...     3.2
#
#                         Company Name         Location  \
# 0           Realtor.com Careers\n3.7       Austin, TX
# 2               Visionary Homes\n4.5  North Logan, UT
# 3                  Kodak Alaris\n4.0    Rochester, NY
# 4             GSK Solutions Inc\n3.9     Richmond, VA
# 5        Cognize Tech Solutions\n2.0           Remote
# ...                              ...              ...
# 7995    Cambia Health Solutions\n3.5     Portland, OR
# 7996           Tellus Solutions\n3.7           Remote
# 7997  Toyota Research Institute\n4.1    Los Altos, CA
# 7998                   Grainger\n4.1      Chicago, IL
# 7999                 Stitch Fix\n3.2           Remote
#
#                          Size  Founded               Type of ownership  \
# 0      1001 to 5000 Employees     1993               Company - Private
# 2         51 to 200 Employees     2004               Company - Private
# 3      1001 to 5000 Employees     2013               Company - Private
# 4           1 to 50 Employees     2010               Company - Private
# 5         51 to 200 Employees       -1               Company - Private
# ...                       ...      ...                             ...
# 7995  5001 to 10000 Employees     1917          Nonprofit Organization
# 7996      51 to 200 Employees     2006               Company - Private
# 7997     201 to 500 Employees     2016  Subsidiary or Business Segment
# 7998         10000+ Employees     1927                Company - Public
# 7999         10000+ Employees     2011                Company - Public
#
#                                      Industry  ...  \
# 0               Computer Hardware Development  ...
# 2                                Construction  ...
# 3     Information Technology Support Services  ...
# 4                         Business Consulting  ...
# 5                                          -1  ...
# ...                                       ...  ...
# 7995         Health Care Services & Hospitals  ...
# 7996  Information Technology Support Services  ...
# 7997                   Research & Development  ...
# 7998                                Wholesale  ...
# 7999                      Other Retail Stores  ...
#
#                                Revenue min_salary  max_salary  avg_salary  \
# 0             Unknown / Non-Applicable        102         148       125.0
# 2             Unknown / Non-Applicable         54          82        68.0
# 3     $500 million to $1 billion (USD)         63          91        77.0
# 4              $5 to $25 million (USD)         72          81        76.5
# 5             Unknown / Non-Applicable         65          85        75.0
# ...                                ...        ...         ...         ...
# 7995          Unknown / Non-Applicable         95         136       115.5
# 7996           $5 to $25 million (USD)         91          93        92.0
# 7997          Unknown / Non-Applicable        152         210       181.0
# 7998                $10+ billion (USD)        128         196       162.0
# 7999            $1 to $5 billion (USD)        160         226       193.0
#
#                       job_title seniority desc_len  tools  techs  education
# 0                  data analyst        na     1206      1      0          0
# 2                  data analyst        na      914      1      0          0
# 3                  data analyst        na     2071      2      0          0
# 4                  data analyst        na      593      1      0          0
# 5                  data analyst        na      901      1      0          0
# ...                         ...       ...      ...    ...    ...        ...
# 7995  machine learning engineer        na     7095      3     15          6
# 7996             data scientist        na      882      1      0          0
# 7997  machine learning engineer        na     4785      3      0          0
# 7998  machine learning engineer    senior     4682      1      0          0
# 7999             data scientist        na     8576      2      0          0
#
# [5964 rows x 21 columns]

# %% [markdown]
# ## 5. Company Name Column

# %% [markdown]
# ### 1. Remove the trailing Rating from the company name
# ### 2. remove the \n from the company name

# %%
# you can see that companies that has -1 Rating, there name is fine
# but companies that has a Rating, there name ends with "\n3.2"
raw_df[['Rating','Company Name']].sample(40)
# Out:
#       Rating                              Company Name
# 6505     4.4                                Adobe\n4.4
# 4257     3.9                      UT Southwestern\n3.9
# 3518    -1.0                                    Zoomph
# 7801     5.0                            Runway AI\n5.0
# 17       4.3                         CT Solutions\n4.3
# 1232     3.2                ITR Concession Co LLC\n3.2
# 802      4.3                         CT Solutions\n4.3
# 2794     3.7                             GoodLeap\n3.7
# 5042    -1.0                          Synapseb systems
# 753      4.5                      Visionary Homes\n4.5
# 2682     2.6                  Tokai Carbon GE LLC\n2.6
# 3335     3.8                           CPS Energy\n3.8
# 443      4.1                             Kitcheck\n4.1
# 5382     3.9                              Parsons\n3.9
# 2416    -1.0                                  Avestacs
# 3244    -1.0                        Kommforcesolutions
# 5590     4.0                       General Motors\n4.0
# 5788    -1.0                                   TeachFX
# 4880     4.1                           Salesforce\n4.1
# 3035     3.2                      Everside Health\n3.2
# 5087     4.1                               Seagen\n4.1
# 4654     3.7                  Realtor.com Careers\n3.7
# 7679     3.9                               Disney\n3.9
# 4520     3.6         Stifel, Nicolaus & Co., Inc.\n3.6
# 1976     4.1                             Kitcheck\n4.1
# 4875     4.3                     Neuberger Berman\n4.3
# 503      5.0                             DSMH LLC\n5.0
# 7078     3.6                                Honor\n3.6
# 7591     4.1                             Grainger\n4.1
# 3041    -1.0                                   RSHARMA
# 2287     3.7                                  ITR\n3.7
# 13       3.9                             McKinney\n3.9
# 4811     3.5                             Dataminr\n3.5
# 1638     3.1           National General Insurance\n3.1
# 7934     3.8                                Bayer\n3.8
# 7375     3.9  The Walt Disney Company (Corporate)\n3.9
# 1507     4.2                       Premier System\n4.2
# 174      3.8                    Miami-Dade County\n3.8
# 2164     4.0               Gray Tier Technologies\n4.0
# 6039     4.3                             Autodesk\n4.3

# %%
# Remove the Rating and /n from the company name tail
raw_df['company_name'] = raw_df['Company Name'].str.replace(r'\n([0-9]\.[0-9])','',regex = True)
raw_df['company_name'] = raw_df['company_name'].str.replace(r'\r','',regex = True)

# %%
len(raw_df['company_name'].unique())
raw_df['company_name'].value_counts().head(60)
# Out:
# Meta                                                            152
# Realtor.com Careers                                             128
# Honor                                                            93
# PayPal                                                           83
# Disney                                                           82
# AI Labs at the American Alliance for International Education     72
# Microsoft                                                        69
# Southwest Airlines                                               67
# Mastercard                                                       63
# Salesforce                                                       62
# Runway AI                                                        61
# Grainger                                                         61
# Visionary Homes                                                  56
# NVIDIA                                                           56
# Prime Therapeutics                                               55
# Kitcheck                                                         53
# Cedar Inc                                                        51
# Juji                                                             49
# US Acute Care Solutions                                          46
# CVS Health                                                       46
# INTEL                                                            44
# TikTok                                                           40
# Abacus.AI                                                        36
# Netflix                                                          35
# Etsy                                                             35
# Cambia Health Solutions                                          35
# KAYAK                                                            35
# Tellus Solutions                                                 34
# Rite Aid                                                         33
# Octaura                                                          33
# Amazon.com Services LLC                                          33
# Konnectingtree                                                   33
# Mission Cloud Services                                           33
# Ambry Genetics Corporation                                       33
# Decision Point Healthcare                                        32
# Discord                                                          32
# FAST GROWING TREES LLC                                           32
# Kiss Products                                                    31
# Activision                                                       31
# Bayer                                                            31
# eimagine                                                         30
# Health Alliance Plan                                             30
# Veracity Software                                                30
# SmarterTravel                                                    30
# National General Insurance                                       30
# CDC Foundation                                                   30
# Neuberger Berman                                                 30
# The Boston Beer Company                                          30
# Nissan                                                           30
# CHISHOLM CHISHOLM & KILPATRICK LTD                               29
# Amex                                                             29
# GE Healthcare                                                    29
# Cognize Tech Solutions                                           29
# ServiceMaster Restoration                                        29
# WALGREENS                                                        29
# AccumTech                                                        29
# CPS Energy                                                       29
# Data Annotation                                                  29
# Recall Masters                                                   29
# PROC9                                                            29
# Name: company_name, dtype: int64

# %% [markdown]
# ## 4. Rating Column

# %%
raw_df['Rating'].value_counts()
# Out:
#  3.9    814
# -1.0    709
#  4.1    521
#  4.0    377
#  3.7    366
#  4.2    319
#  4.3    317
#  5.0    286
#  3.8    262
#  3.2    261
#  3.6    231
#  3.5    217
#  3.4    184
#  4.6    157
#  4.4    148
#  3.1    135
#  4.5    126
#  3.3     91
#  3.0     76
#  4.7     67
#  4.9     66
#  4.8     63
#  2.7     61
#  2.0     48
#  2.9     31
#  2.8     15
#  2.6      6
#  2.4      4
#  1.0      4
#  2.3      2
# Name: Rating, dtype: int64

# %%
raw_df.loc[raw_df['Rating'] == -1, 'company_name'].value_counts()
# Out:
# AI Labs at the American Alliance for International Education    72
# Juji                                                            49
# Konnectingtree                                                  33
# Data Annotation                                                 29
# PROC9                                                           29
#                                                                 ..
# Cilable                                                          1
# Slesha inc                                                       1
# Celerens                                                         1
# Trail Blazer                                                     1
# MDACCESS                                                         1
# Name: company_name, Length: 97, dtype: int64

# %%
raw_df.loc[raw_df['company_name'] == 'Juji', 'Rating'] = 4.0

# %%
raw_df.loc[raw_df['company_name'] == 'Konnectingtree', 'Rating'] = 4.4

# %%
raw_df.loc[raw_df['company_name'] == 'AI Labs at the American Alliance for International Education']
# Out:
#                                               Job Title  \
# 6005  Research Scientist: Machine Learning & AI (Rem...
# 6013  Principal Machine Learning Engineers (Remote/P...
# 6235  Research Scientist: Machine Learning & AI (Rem...
# 6265  Research Scientist: Machine Learning & AI (Rem...
# 6291  Research Scientist: Machine Learning & AI (Rem...
# ...                                                 ...
# 7920  Research Scientist: Machine Learning & AI (Rem...
# 7944  Principal Machine Learning Engineers (Remote/P...
# 7950  Research Scientist: Machine Learning & AI (Rem...
# 7974  Principal Machine Learning Engineers (Remote/P...
# 7980  Research Scientist: Machine Learning & AI (Rem...
#
#                                         Salary Estimate  \
# 6005  Employer Provided Salary:$70.00 - $120.00 Per ...
# 6013  Employer Provided Salary:$65.00 - $120.00 Per ...
# 6235  Employer Provided Salary:$70.00 - $120.00 Per ...
# 6265  Employer Provided Salary:$70.00 - $120.00 Per ...
# 6291  Employer Provided Salary:$70.00 - $120.00 Per ...
# ...                                                 ...
# 7920  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7944  Employer Provided Salary:$65.00 - $120.00 Per ...
# 7950  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7974  Employer Provided Salary:$65.00 - $120.00 Per ...
# 7980  Employer Provided Salary:$70.00 - $120.00 Per ...
#
#                                         Job Description  Rating  \
# 6005  This is a part-time and remote job for Researc...    -1.0
# 6013  This is a part-time and remote job for Princip...    -1.0
# 6235  This is a part-time and remote job for Researc...    -1.0
# 6265  This is a part-time and remote job for Researc...    -1.0
# 6291  This is a part-time and remote job for Researc...    -1.0
# ...                                                 ...     ...
# 7920  This is a part-time and remote job for Researc...    -1.0
# 7944  This is a part-time and remote job for Princip...    -1.0
# 7950  This is a part-time and remote job for Researc...    -1.0
# 7974  This is a part-time and remote job for Princip...    -1.0
# 7980  This is a part-time and remote job for Researc...    -1.0
#
#                                            Company Name Location Size  \
# 6005  AI Labs at the American Alliance for Internati...   Remote   -1
# 6013  AI Labs at the American Alliance for Internati...   Remote   -1
# 6235  AI Labs at the American Alliance for Internati...   Remote   -1
# 6265  AI Labs at the American Alliance for Internati...   Remote   -1
# 6291  AI Labs at the American Alliance for Internati...   Remote   -1
# ...                                                 ...      ...  ...
# 7920  AI Labs at the American Alliance for Internati...   Remote   -1
# 7944  AI Labs at the American Alliance for Internati...   Remote   -1
# 7950  AI Labs at the American Alliance for Internati...   Remote   -1
# 7974  AI Labs at the American Alliance for Internati...   Remote   -1
# 7980  AI Labs at the American Alliance for Internati...   Remote   -1
#
#       Founded Type of ownership Industry  ... min_salary max_salary  \
# 6005       -1                -1       -1  ...        126        216
# 6013       -1                -1       -1  ...        117        216
# 6235       -1                -1       -1  ...        126        216
# 6265       -1                -1       -1  ...        126        216
# 6291       -1                -1       -1  ...        126        216
# ...       ...               ...      ...  ...        ...        ...
# 7920       -1                -1       -1  ...        126        216
# 7944       -1                -1       -1  ...        117        216
# 7950       -1                -1       -1  ...        126        216
# 7974       -1                -1       -1  ...        117        216
# 7980       -1                -1       -1  ...        126        216
#
#       avg_salary                  job_title  seniority desc_len tools  techs  \
# 6005       171.0  machine learning engineer         na      947     1      0
# 6013       166.5  machine learning engineer     senior      910     1      0
# 6235       171.0  machine learning engineer         na      947     1      0
# 6265       171.0  machine learning engineer         na      947     1      0
# 6291       171.0  machine learning engineer         na      947     1      0
# ...          ...                        ...        ...      ...   ...    ...
# 7920       171.0  machine learning engineer         na     2764     2     15
# 7944       166.5  machine learning engineer     senior     2600     2     15
# 7950       171.0  machine learning engineer         na     2764     2     15
# 7974       166.5  machine learning engineer     senior     2600     2     15
# 7980       171.0  machine learning engineer         na     2764     2     15
#
#       education                                       company_name
# 6005          0  AI Labs at the American Alliance for Internati...
# 6013          0  AI Labs at the American Alliance for Internati...
# 6235          0  AI Labs at the American Alliance for Internati...
# 6265          0  AI Labs at the American Alliance for Internati...
# 6291          0  AI Labs at the American Alliance for Internati...
# ...         ...                                                ...
# 7920          6  AI Labs at the American Alliance for Internati...
# 7944          6  AI Labs at the American Alliance for Internati...
# 7950          6  AI Labs at the American Alliance for Internati...
# 7974          6  AI Labs at the American Alliance for Internati...
# 7980          6  AI Labs at the American Alliance for Internati...
#
# [72 rows x 22 columns]

# %%
raw_df.loc[raw_df['Rating']== -1, 'company_name'].value_counts()
# Out:
# AI Labs at the American Alliance for International Education    29
# PROC9                                                           29
# Proof                                                           28
# I20 Technologies                                                24
# Kommforcesolutions                                              24
#                                                                 ..
# Cal-Tex Protective Coatings, Inc.                                1
# Cilable                                                          1
# Slesha inc                                                       1
# Celerens                                                         1
# MDACCESS                                                         1
# Name: company_name, Length: 94, dtype: int64

# %%
raw_df= raw_df.loc[raw_df['company_name'] != 'Data Annotation']

# %% [markdown]
# ## 6. Company Location Column

# %% [markdown]
# ### 1. Remove the Name of the States, Keep only the abbreviation
# ### 2. Deal with anomalies ['Texas', 'United States', 'New York State']

# %%
raw_df['Location'].sample(60)
# Out:
# 137                   Remote
# 1056                  Remote
# 6362              Austin, TX
# 561     Saint Petersburg, FL
# 6393                  Remote
# 3393              Reston, VA
# 2146             Chicago, IL
# 7311            Portland, OR
# 7599       San Francisco, CA
# 3115         Chapel Hill, NC
# 3451              Boston, MA
# 2109         Chattanooga, TN
# 7876                  Remote
# 6399       San Francisco, CA
# 4472    South Sioux City, NE
# 5313                  Remote
# 5760       New Brunswick, NJ
# 3926            Somerset, NJ
# 6772                  Remote
# 7229                  Remote
# 3181             Phoenix, AZ
# 6251                  Remote
# 2067         North Wales, PA
# 4180              Austin, TX
# 1961             Seattle, WA
# 339                   Remote
# 7321              Dallas, TX
# 6382       San Francisco, CA
# 6624         Lake Forest, IL
# 4055              Durham, NC
# 1632             Seattle, WA
# 4755            New York, NY
# 7500                  Remote
# 7491                  Remote
# 5663              Dallas, TX
# 129         Indianapolis, IN
# 104             New York, NY
# 7998             Chicago, IL
# 3164           United States
# 88               Atlanta, GA
# 193            Cambridge, MA
# 5385            New York, NY
# 2204           Beaverton, OR
# 7530                Illinois
# 2444           Fort Mill, SC
# 6010           Palo Alto, CA
# 7746                  Remote
# 3169                  Remote
# 5682                  Remote
# 3141         Aliso Viejo, CA
# 1658           Nashville, TN
# 755              Houston, TX
# 6281                  Remote
# 1534           Nashville, TN
# 5915            New York, NY
# 4022            New York, NY
# 6660                  Remote
# 5369                  Remote
# 7180            San Jose, CA
# 1775                  Remote
# Name: Location, dtype: object

# %%
# Remove the name of the States, keep the abbreviations
raw_df['job_state'] = raw_df['Location'].apply(lambda x: x.split(',')[1] if len(str(x).split(',')) > 1 else x)
raw_df['job_state'] = raw_df['job_state'].str.strip()

# %%
# Turns out we have 4 abnormal values [ united States, Texas, Remote, New York State]
raw_df['job_state'].value_counts()
# Out:
# Remote            1542
# CA                 974
# NY                 758
# TX                 520
# MA                 195
# IL                 175
# VA                 120
# OH                 112
# WA                 106
# DC                 105
# NJ                  99
# MO                  94
# NC                  87
# FL                  76
# IN                  76
# MI                  75
# TN                  70
# GA                  70
# MD                  65
# UT                  61
# NE                  55
# PA                  50
# United States       47
# OR                  43
# Texas               37
# AZ                  31
# California          30
# MN                  28
# RI                  26
# Indiana             24
# Illinois            23
# WI                  18
# SC                  15
# KY                  14
# CO                  12
# AR                  11
# WV                   7
# ND                   6
# NV                   6
# Oregon               5
# DE                   5
# CT                   5
# Pennsylvania         5
# PR                   4
# New York State       2
# AL                   1
# Name: job_state, dtype: int64

# %%
# Turn out all the 7 united states are in lyra health company , after i did my research; it is located in california(CA)
raw_df.loc[raw_df['job_state'] == 'United States','company_name'].value_counts()
# Out:
# Blue Cross Blue Shield of Arizona    19
# Miami-Dade County                    10
# Lyra Health                           7
# Microsoft                             5
# Getty Images                          2
# PTYTECH LLC                           1
# MeridianLink                          1
# ADPEARANCE HOLDINGS LLC               1
# Attentive Mobile                      1
# Name: company_name, dtype: int64

# %%
raw_df.loc[raw_df['company_name'] == 'Blue Cross Blue Shield of Arizona' , 'job_state'] = 'AZ'

# %%
raw_df.loc[raw_df['company_name'] == 'Miami-Dade County' , 'job_state'] = 'FL'

# %%
raw_df['job_state'].replace({'Texas':'TX','New York State' : 'NY','Oregon':'OR','California':'CA',
                            'Pennsylvania': 'PA','Illinois' : 'IL' ,'Indiana':'IN', 'United States' : 'CA'}, inplace =True)

# %%
raw_df['job_state'].value_counts()
# Out:
# Remote    1542
# CA        1022
# NY         760
# TX         557
# IL         198
# MA         195
# VA         120
# OH         112
# WA         106
# DC         105
# IN         100
# NJ          99
# MO          94
# NC          87
# FL          86
# MI          75
# TN          70
# GA          70
# MD          65
# UT          61
# NE          55
# PA          55
# AZ          50
# OR          48
# MN          28
# RI          26
# WI          18
# SC          15
# KY          14
# CO          12
# AR          11
# WV           7
# ND           6
# NV           6
# DE           5
# CT           5
# PR           4
# AL           1
# Name: job_state, dtype: int64

# %%
us_states_df = pd.read_excel(US_STATES_ABBR)
us_states_df.head(20)
# Out:
#                    state abbr
# 0                Alabama   AL
# 1                 Alaska   AK
# 2                Arizona   AZ
# 3               Arkansas   AR
# 4         American Samoa   AS
# 5             California   CA
# 6               Colorado   CO
# 7            Connecticut   CT
# 8               Delaware   DE
# 9   District of Columbia   DC
# 10               Florida   FL
# 11               Georgia   GA
# 12                  Guam   GU
# 13                Hawaii   HI
# 14                 Idaho   ID
# 15              Illinois   IL
# 16               Indiana   IN
# 17                  Iowa   IA
# 18                Kansas   KS
# 19              Kentucky   KY

# %%
# add the name of the state with abbreviation for the observability
raw_df['job_state'] = raw_df.job_state.apply(lambda x: us_states_df[us_states_df['abbr'] == x].values[0][0] + "-" + x if x in us_states_df['abbr'].value_counts() else 'Remote')

# %%
raw_df['job_state']
# Out:
# 0            Texas-TX
# 2             Utah-UT
# 3         New York-NY
# 4         Virginia-VA
# 5              Remote
#             ...
# 7995        Oregon-OR
# 7996           Remote
# 7997    California-CA
# 7998      Illinois-IL
# 7999           Remote
# Name: job_state, Length: 5892, dtype: object

# %% [markdown]
# ## 7. Company Size Column

# %%
raw_df['Size'].value_counts()
# Out:
# 10000+ Employees           1587
# 1001 to 5000 Employees     1031
# 51 to 200 Employees        1003
# 1 to 50 Employees           702
# 501 to 1000 Employees       371
# 5001 to 10000 Employees     338
# -1                          323
# 201 to 500 Employees        308
# Unknown                     229
# Name: Size, dtype: int64

# %%
# National Security Agency 
raw_df.loc[raw_df['Size'] == 'Unknown', 'company_name'].value_counts()
# Out:
# Proof                                    28
# Tarzana Treatment Center                 25
# National Security Agency                 21
# SentiLink                                18
# EQ community                             17
# Reuben Cooley Inc.                       15
# Luttechub                                14
# Ryzen Solutions                          14
# Intellibus                               14
# Market Tree Research                      7
# Changing Technologies, Inc.               4
# University of Minnesota                   4
# GTA (Global Technology Associates)        3
# Tegria                                    2
# inAssist                                  2
# Fabrx Space                               2
# ZENOTIS                                   2
# AVS Solutions INC                         2
# Goodwill                                  2
# ITR Concession Co LLC                     2
# Moorecroft Systems                        2
# Tech brothers infoservices                2
# ClientSolv Technologies                   2
# Enigma                                    2
# VirtualHealth                             2
# Procal Technologies                       1
# OpenTeams                                 1
# Celerens                                  1
# Vetro Tech Inc                            1
# 80 Acres Farms                            1
# PUTNAM RECRUITING GROUP                   1
# TechCoreGlobal                            1
# Mind Mint                                 1
# iSpot.tv                                  1
# 2K                                        1
# RevOpsforce                               1
# Keyrus USA                                1
# Bethesda Corporate                        1
# Supremus                                  1
# Sana Pivot Inc                            1
# WA River Protection Solutions             1
# Wisefolks Technologies                    1
# HEALTHCHOICE                              1
# Swivel Payment Solutions, LLC             1
# Information Systems Consultants, Inc.     1
# Amazon Web Services, Inc.                 1
# Name: company_name, dtype: int64

# %%
raw_df.loc[raw_df['Size'] == '-1', 'company_name'].value_counts()
# Out:
# AI Labs at the American Alliance for International Education    29
# PROC9                                                           29
# Kommforcesolutions                                              24
# I20 Technologies                                                24
# AKT Corp                                                        22
# Alliance International CHB, Inc.                                22
# gointellects                                                    18
# Trenchant Employee Services Limited                             16
# Infobahn Solutions Inc.                                         13
# Omniware LLC                                                    11
# Greenbrier Government Solutions                                  9
# Mirage Studio (YC S20)                                           8
# Fulcrum Analytics                                                8
# Egen Solutions Inc                                               7
# Cloudrex                                                         7
# RSHARMA                                                          5
# Cybotic System                                                   4
# Percept Health                                                   4
# Konnectingtree.Inc                                               4
# Arch Systems, LLC                                                4
# The Range NYC LLC                                                4
# Junior Achievement USA                                           4
# PRISM IT LLC                                                     4
# Celink                                                           3
# Upen Group Inc                                                   3
# CloudSoftSync                                                    3
# DLZP Group                                                       3
# NewLimit                                                         3
# KONNECTINGTREE INC                                               3
# Softsnippets Inc                                                 3
# Vandved Search                                                   2
# Quicklly.com                                                     2
# Sera Talent                                                      2
# Leon                                                             2
# UtiliSave LLC                                                    2
# Antimetal                                                        1
# Clostra                                                          1
# Gointellects Inc.                                                1
# COREHIRE                                                         1
# Slesha inc                                                       1
# Kakudi Inc.                                                      1
# Eagle Outsourcing Pte ltd                                        1
# Trail Blazer                                                     1
# Point Predictive, Inc.                                           1
# Microflexinfra                                                   1
# CODING DOJO INC.                                                 1
# MDACCESS                                                         1
# Name: company_name, dtype: int64

# %%
# change national security agency and university of minnesota to 10000+ employess
raw_df.loc[raw_df['company_name'] == 'National Security Agency', 'Size'] = '10000+ Employees'

# %%
raw_df.loc[raw_df['company_name'] == 'University of Minnesota', 'Size'] = '10000+ Employees'

# %%
raw_df.loc[raw_df['company_name'] == 'SentiLink', 'Size'] = '1 to 50 Employees'

# %%
raw_df= raw_df.loc[raw_df['company_name'] != 'Data Annotation']

# %%
# turn the unknowns to -1
raw_df.loc[raw_df['Size'] == 'Unknown', 'Size']= '-1'

# %%
raw_df.loc[raw_df['Size'] == '-1', 'company_name'].value_counts()
# Out:
# AI Labs at the American Alliance for International Education    29
# PROC9                                                           29
# Proof                                                           28
# Tarzana Treatment Center                                        25
# Kommforcesolutions                                              24
#                                                                 ..
# HEALTHCHOICE                                                     1
# iSpot.tv                                                         1
# 80 Acres Farms                                                   1
# Slesha inc                                                       1
# Amazon Web Services, Inc.                                        1
# Name: company_name, Length: 90, dtype: int64

# %%
raw_df['Size'].value_counts(sort = True)
# Out:
# 10000+ Employees           1612
# 1001 to 5000 Employees     1031
# 51 to 200 Employees        1003
# 1 to 50 Employees           720
# -1                          509
# 501 to 1000 Employees       371
# 5001 to 10000 Employees     338
# 201 to 500 Employees        308
# Name: Size, dtype: int64

# %% [markdown]
# ## 8. Founded Column

# %% [markdown]
# ### 1. get the age of the company instead of the year found
# ### 2. Figure Out where the -1 values coming From
# ### 3. Search for the Founded year for the companies that have alot of appearances in the df and replace the values

# %%
raw_df = raw_df.copy()
raw_df['age']= raw_df.Founded.apply(lambda x: x if x < 1 else 2023 - x)

# %%
len(raw_df[raw_df['age'] == -1])
# Out:
# 1186

# %%
raw_df[(raw_df['age'] == -1) & (raw_df['job_state'] == 'Remote')]
# Out:
#                                               Job Title  \
# 5                                          Data Analyst
# 26                                         Data Analyst
# 36                                      Tableau Analyst
# 48                                     Sr. Data Analyst
# 139                                    Business Analyst
# ...                                                 ...
# 7377  Research Scientist: Machine Learning & AI (Rem...
# 7384  Principal Machine Learning Engineers (Remote/P...
# 7398  Research Scientist: Machine Learning & AI (Rem...
# 7413  Principal Machine Learning Engineers (Remote/P...
# 7808                               Staff Data Scientist
#
#                                         Salary Estimate  \
# 5                  Employer Provided Salary:$65K - $85K
# 26                Employer Provided Salary:$70K - $120K
# 36    Employer Provided Salary:$45.00 - $50.00 Per Hour
# 48    Employer Provided Salary:$46.00 - $52.00 Per Hour
# 139                Employer Provided Salary:$65K - $80K
# ...                                                 ...
# 7377  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7384  Employer Provided Salary:$65.00 - $120.00 Per ...
# 7398  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7413  Employer Provided Salary:$65.00 - $120.00 Per ...
# 7808             Employer Provided Salary:$180K - $230K
#
#                                         Job Description  Rating  \
# 5      Responsible for the design, development and ...     2.0
# 26    Title : Data Analyst / Data Engineer\nLocation...    -1.0
# 36    Locations: Remote with few days in a month in ...     4.0
# 48    Job Requirements:\nData Cleaning – identify er...     2.0
# 139   Gather data, analyze, and make recommendation...     2.0
# ...                                                 ...     ...
# 7377  This is a part-time and remote job for Researc...    -1.0
# 7384  This is a part-time and remote job for Princip...    -1.0
# 7398  This is a part-time and remote job for Researc...    -1.0
# 7413  This is a part-time and remote job for Princip...    -1.0
# 7808  SentiLink is building the future of identity v...     5.0
#
#                                            Company Name Location  \
# 5                           Cognize Tech Solutions\n2.0   Remote
# 26                                             AKT Corp   Remote
# 36                             IndoMinds Solutions\n4.0   Remote
# 48                                     Altak Group\n2.0   Remote
# 139                         Cognize Tech Solutions\n2.0   Remote
# ...                                                 ...      ...
# 7377  AI Labs at the American Alliance for Internati...   Remote
# 7384  AI Labs at the American Alliance for Internati...   Remote
# 7398  AI Labs at the American Alliance for Internati...   Remote
# 7413  AI Labs at the American Alliance for Internati...   Remote
# 7808                                     SentiLink\n5.0   Remote
#
#                      Size  Founded  Type of ownership  \
# 5     51 to 200 Employees       -1  Company - Private
# 26                     -1       -1                 -1
# 36      1 to 50 Employees       -1            Unknown
# 48      1 to 50 Employees       -1  Company - Private
# 139   51 to 200 Employees       -1  Company - Private
# ...                   ...      ...                ...
# 7377                   -1       -1                 -1
# 7384                   -1       -1                 -1
# 7398                   -1       -1                 -1
# 7413                   -1       -1                 -1
# 7808    1 to 50 Employees       -1   Company - Public
#
#                                      Industry  ... avg_salary  \
# 5                                          -1  ...       75.0
# 26                                         -1  ...       95.0
# 36                                         -1  ...       85.5
# 48                                         -1  ...       87.5
# 139                                        -1  ...       72.5
# ...                                       ...  ...        ...
# 7377                                       -1  ...      171.0
# 7384                                       -1  ...      166.5
# 7398                                       -1  ...      171.0
# 7413                                       -1  ...      166.5
# 7808  Information Technology Support Services  ...      205.0
#
#                       job_title  seniority  desc_len  tools techs education  \
# 5                  data analyst         na       901      1     0         0
# 26                 data analyst         na       415      1     0         0
# 36                 data analyst         na       368      1     0         0
# 48                 data analyst     senior       621      1     0         0
# 139                data analyst         na       621      1     0         0
# ...                         ...        ...       ...    ...   ...       ...
# 7377  machine learning engineer         na      2764      2    15         6
# 7384  machine learning engineer     senior      2600      2    15         6
# 7398  machine learning engineer         na      2764      2    15         6
# 7413  machine learning engineer     senior      2600      2    15         6
# 7808             data scientist         na      4756      1     0         0
#
#                                            company_name  job_state  age
# 5                                Cognize Tech Solutions     Remote   -1
# 26                                             AKT Corp     Remote   -1
# 36                                  IndoMinds Solutions     Remote   -1
# 48                                          Altak Group     Remote   -1
# 139                              Cognize Tech Solutions     Remote   -1
# ...                                                 ...        ...  ...
# 7377  AI Labs at the American Alliance for Internati...     Remote   -1
# 7384  AI Labs at the American Alliance for Internati...     Remote   -1
# 7398  AI Labs at the American Alliance for Internati...     Remote   -1
# 7413  AI Labs at the American Alliance for Internati...     Remote   -1
# 7808                                          SentiLink     Remote   -1
#
# [448 rows x 24 columns]

# %%
raw_df[(raw_df['age'] == -1) & ~(raw_df['job_state'] == 'Remote')]
# Out:
#                                     Job Title  \
# 9                                Data Analyst
# 10                               Data Analyst
# 15                     Data Analyst Associate
# 17                    E-Commerce Data Analyst
# 27                          SFDC Data Analyst
# ...                                       ...
# 6972     Artificial Intelligence (AI) Trainer
# 6998       Machine Learning Research Engineer
# 7025                Machine Learning Engineer
# 7038  Data Science & People Reporting Analyst
# 7068  Data Science & People Reporting Analyst
#
#                                         Salary Estimate  \
# 9                  Employer Provided Salary:$55K - $70K
# 10                 Employer Provided Salary:$79K - $96K
# 15             Employer Provided Salary:$30.00 Per Hour
# 17    Employer Provided Salary:$30.00 - $35.00 Per Hour
# 27                         $58K - $82K (Glassdoor est.)
# ...                                                 ...
# 6972                     $102K - $161K (Glassdoor est.)
# 6998             Employer Provided Salary:$125K - $180K
# 7025  Employer Provided Salary:$40.00 - $55.00 Per Hour
# 7038             Employer Provided Salary:$115K - $170K
# 7068             Employer Provided Salary:$115K - $170K
#
#                                         Job Description  Rating  \
# 9     Holland Homes is in search of someone who has ...     2.3
# 10    We are looking for a passionate certified Data...    -1.0
# 15    ONLY US AND GC CANDIDATE\nJob Title: Data Anal...     5.0
# 17    Ecommerce Data Analyst\n6 months contract\nAus...     4.3
# 27    Convera has embarked on a major business trans...     2.7
# ...                                                 ...     ...
# 6972  We are seeking highly motivated and talented A...     4.0
# 6998  About this role\nIn this role, you will design...    -1.0
# 7025  Subject: Machine Learning engineer- PHILADELPH...    -1.0
# 7038  Sera Talent is supporting our client who is se...    -1.0
# 7068  Sera Talent is supporting our client who is se...    -1.0
#
#                  Company Name          Location                    Size  \
# 9     Holland Homes, LLC\n2.3        Auburn, AL       1 to 50 Employees
# 10                   KesarWeb        Fresno, CA       1 to 50 Employees
# 15       DAtec Solutions\n5.0        McLean, VA       1 to 50 Employees
# 17          CT Solutions\n4.3        Austin, TX     51 to 200 Employees
# 27               Convera\n2.7         Omaha, NE  1001 to 5000 Employees
# ...                       ...               ...                     ...
# 6972                     Juji      San Jose, CA       1 to 50 Employees
# 6998   Mirage Studio (YC S20)      New York, NY                      -1
# 7025           TechCoreGlobal  Philadelphia, PA                      -1
# 7038              Sera Talent      New York, NY                      -1
# 7068              Sera Talent      New York, NY                      -1
#
#       Founded  Type of ownership                          Industry  ...  \
# 9          -1  Company - Private                                -1  ...
# 10         -1  Company - Private                                -1  ...
# 15         -1  Company - Private                                -1  ...
# 17         -1  Company - Private                 Beauty & Wellness  ...
# 27         -1   Company - Public  Financial Transaction Processing  ...
# ...       ...                ...                               ...  ...
# 6972       -1   Company - Public                                -1  ...
# 6998       -1                 -1                                -1  ...
# 7025       -1   Company - Public                                -1  ...
# 7038       -1                 -1                                -1  ...
# 7068       -1                 -1                                -1  ...
#
#      avg_salary                  job_title  seniority  desc_len  tools techs  \
# 9          62.5               data analyst         na       642      1     0
# 10         87.5               data analyst         na       852      1     0
# 15         54.0               data analyst         na       319      1     0
# 17         58.5               data analyst         na       356      1     0
# 27         70.0               data analyst         na      2336      1     0
# ...         ...                        ...        ...       ...    ...   ...
# 6972      131.5  machine learning engineer         na       732      1     0
# 6998      152.5  machine learning engineer         na       668      1     0
# 7025       85.5  machine learning engineer         na       927      1     0
# 7038      142.5             data scientist         na      1433      1     0
# 7068      142.5             data scientist         na      1433      1     0
#
#      education            company_name        job_state  age
# 9            0      Holland Homes, LLC       Alabama-AL   -1
# 10           0                KesarWeb    California-CA   -1
# 15           0         DAtec Solutions      Virginia-VA   -1
# 17           0            CT Solutions         Texas-TX   -1
# 27           0                 Convera      Nebraska-NE   -1
# ...        ...                     ...              ...  ...
# 6972         0                    Juji    California-CA   -1
# 6998         0  Mirage Studio (YC S20)      New York-NY   -1
# 7025         0          TechCoreGlobal  Pennsylvania-PA   -1
# 7038         0             Sera Talent      New York-NY   -1
# 7068         0             Sera Talent      New York-NY   -1
#
# [738 rows x 24 columns]

# %%
len(raw_df[(raw_df['age'] == -1) & (raw_df['job_state'] == 'Remote')])
# Out:
# 448

# %%
len(raw_df[(raw_df['age'] == -1) & ~(raw_df['job_state'] == 'Remote')])
# Out:
# 738

# %%
len(raw_df[(raw_df['age'] == -1) & (raw_df['company_name'] == 'Juji')])
# Out:
# 49

# %%
# Turns out Juji Company was founded in 2014, so we can change the age to 9 years
raw_df.loc[raw_df['company_name'] == 'Juji', 'age'] = 9

# %%
# there is 9 (-1) coming from Konnecting Tree company, which was founded in 2016, which is 7 years
raw_df.loc[raw_df['company_name'] == 'Konnectingtree', 'age'] = 7

# %%
# there is 4 (-1) coming from Cadent Company, which was founded in 2016, which is 7 years
raw_df.loc[raw_df['company_name'] == 'Cadent', 'age'] = 7

# %%
len(raw_df[(raw_df['age'] == -1)])
# Out:
# 1100

# %%
raw_df['age'].value_counts(sort=True)
# Out:
# -1      1100
#  19      286
#  7       250
#  8       247
#  25      242
#         ...
#  242       1
#  174       1
#  212       1
#  50        1
#  192       1
# Name: age, Length: 123, dtype: int64

# %%
raw_df.loc[raw_df['age'] == -1 , 'company_name'].value_counts().head(60)
# Out:
# CDC Foundation                                                  30
# Cognize Tech Solutions                                          29
# AI Labs at the American Alliance for International Education    29
# AccumTech                                                       29
# CHISHOLM CHISHOLM & KILPATRICK LTD                              29
# PROC9                                                           29
# DSMH LLC                                                        27
# RADcube, LLC                                                    27
# I20 Technologies                                                24
# Kommforcesolutions                                              24
# AKT Corp                                                        22
# Alliance International CHB, Inc.                                22
# Gray Digital                                                    20
# Proits Hub LLC                                                  20
# Norwin                                                          18
# gointellects                                                    18
# SentiLink                                                       18
# Atlas Labs                                                      18
# Convera                                                         18
# Expro                                                           17
# EQ community                                                    17
# BACloudSystems                                                  17
# Trenchant Employee Services Limited                             16
# LeewayHertz                                                     15
# Reuben Cooley Inc.                                              15
# CentillionZ IT Solutions                                        14
# Luttechub                                                       14
# Ryzen Solutions                                                 14
# Kaizen Analytix                                                 13
# Pison Technology                                                13
# Infobahn Solutions Inc.                                         13
# The Prospective Group (TPG)                                     13
# CT Solutions                                                    13
# MetaPhase Consulting                                            13
# AMB Sports + Entertainment                                      12
# STAND 8                                                         11
# Omniware LLC                                                    11
# Hayward Group, LLC                                              11
# AG Grace Inc                                                    10
# Greenbrier Government Solutions                                  9
# Upward Health                                                    9
# ITR                                                              9
# AppsIntegration.Inc                                              9
# Rothe Development, Inc.                                          9
# Fulcrum Analytics                                                8
# Mirage Studio (YC S20)                                           8
# Syneos Health Clinical                                           7
# Swift Technologies Inc                                           7
# Egen Solutions Inc                                               7
# Cloudrex                                                         7
# Market Tree Research                                             7
# Clairvoyant Inc.                                                 6
# Sancorp Consulting, LLC                                          6
# Cortrack Solutions Pvt Ltd.                                      6
# Global Enterprise Services, LLC                                  6
# BEUMER Group                                                     6
# Synthetaic                                                       5
# RSHARMA                                                          5
# Foxconn Corporation                                              5
# Great Eastern Resort Management, Inc.                            5
# Name: company_name, dtype: int64

# %% [markdown]
# ## 9.Type of ownership

# %%
raw_df['Type of ownership'].value_counts()
# Out:
# Company - Private                 2557
# Company - Public                  2187
# -1                                 323
# Subsidiary or Business Segment     279
# Nonprofit Organization             240
# Self-employed                      105
# Government                          62
# Private Practice / Firm             39
# Unknown                             35
# College / University                29
# Contract                            17
# School / School District            13
# Hospital                             6
# Name: Type of ownership, dtype: int64

# %%
raw_df.loc[raw_df['Type of ownership'] == '-1', 'Type of ownership'] = -1

# %%
raw_df.loc[raw_df['Type of ownership'] == 'Unknown', 'Type of ownership'] = -1

# %%
raw_df.loc[raw_df['Type of ownership'] == 'Contract', 'Type of ownership'] = -1

# %%
raw_df['Type of ownership'].value_counts()
# Out:
# Company - Private                 2557
# Company - Public                  2187
# -1                                 375
# Subsidiary or Business Segment     279
# Nonprofit Organization             240
# Self-employed                      105
# Government                          62
# Private Practice / Firm             39
# College / University                29
# School / School District            13
# Hospital                             6
# Name: Type of ownership, dtype: int64

# %%
raw_df[raw_df['Type of ownership'] == 'Subsidiary or Business Segment']
# Out:
#                                               Job Title  \
# 13                                         Data Analyst
# 28                                         Data Analyst
# 54                                   Sales Data Analyst
# 193                                        Data Analyst
# 198                                  Sales Data Analyst
# ...                                                 ...
# 7877  Machine Learning Research Scientist - Natural ...
# 7907  Machine Learning Research Scientist - Natural ...
# 7937  Machine Learning Research Scientist - Natural ...
# 7967  Machine Learning Research Scientist - Natural ...
# 7997  Machine Learning Research Scientist - Natural ...
#
#                              Salary Estimate  \
# 13             $67K - $101K (Glassdoor est.)
# 28      Employer Provided Salary:$75K - $90K
# 54      Employer Provided Salary:$85K - $95K
# 193     Employer Provided Salary:$75K - $90K
# 198     Employer Provided Salary:$85K - $95K
# ...                                      ...
# 7877  Employer Provided Salary:$152K - $210K
# 7907  Employer Provided Salary:$152K - $210K
# 7937  Employer Provided Salary:$152K - $210K
# 7967  Employer Provided Salary:$152K - $210K
# 7997  Employer Provided Salary:$152K - $210K
#
#                                         Job Description  Rating  \
# 13    JOB RESPONSIBILITIES\n\nThe Data Analyst trans...     3.9
# 28    Job Summary:\n\nThe Data Analyst team at Smart...     3.8
# 54    Dermalogica continues to dominate the professi...     3.5
# 193   Job Summary:\n\nThe Data Analyst team at Smart...     3.8
# 198   Dermalogica continues to dominate the professi...     3.5
# ...                                                 ...     ...
# 7877  At Toyota Research Institute (TRI), we’re on a...     4.1
# 7907  At Toyota Research Institute (TRI), we’re on a...     4.1
# 7937  At Toyota Research Institute (TRI), we’re on a...     4.1
# 7967  At Toyota Research Institute (TRI), we’re on a...     4.1
# 7997  At Toyota Research Institute (TRI), we’re on a...     4.1
#
#                         Company Name       Location                  Size  \
# 13                     McKinney\n3.9   New York, NY   51 to 200 Employees
# 28                SmarterTravel\n3.8  Cambridge, MA   51 to 200 Employees
# 54              Dermalogica LLC\n3.5     Carson, CA  201 to 500 Employees
# 193               SmarterTravel\n3.8  Cambridge, MA   51 to 200 Employees
# 198             Dermalogica LLC\n3.5     Carson, CA  201 to 500 Employees
# ...                              ...            ...                   ...
# 7877  Toyota Research Institute\n4.1  Los Altos, CA  201 to 500 Employees
# 7907  Toyota Research Institute\n4.1  Los Altos, CA  201 to 500 Employees
# 7937  Toyota Research Institute\n4.1  Los Altos, CA  201 to 500 Employees
# 7967  Toyota Research Institute\n4.1  Los Altos, CA  201 to 500 Employees
# 7997  Toyota Research Institute\n4.1  Los Altos, CA  201 to 500 Employees
#
#       Founded               Type of ownership                        Industry  \
# 13       1969  Subsidiary or Business Segment  Advertising & Public Relations
# 28       1998  Subsidiary or Business Segment         Internet & Web Services
# 54       1986  Subsidiary or Business Segment  Consumer Product Manufacturing
# 193      1998  Subsidiary or Business Segment         Internet & Web Services
# 198      1986  Subsidiary or Business Segment  Consumer Product Manufacturing
# ...       ...                             ...                             ...
# 7877     2016  Subsidiary or Business Segment          Research & Development
# 7907     2016  Subsidiary or Business Segment          Research & Development
# 7937     2016  Subsidiary or Business Segment          Research & Development
# 7967     2016  Subsidiary or Business Segment          Research & Development
# 7997     2016  Subsidiary or Business Segment          Research & Development
#
#       ... avg_salary                  job_title  seniority  desc_len  tools  \
# 13    ...       84.0               data analyst         na      6311      1
# 28    ...       82.5               data analyst         na       772      1
# 54    ...       90.0               data analyst         na      1353      1
# 193   ...       82.5               data analyst         na       772      1
# 198   ...       90.0               data analyst         na      1353      1
# ...   ...        ...                        ...        ...       ...    ...
# 7877  ...      181.0  machine learning engineer         na      4785      3
# 7907  ...      181.0  machine learning engineer         na      4785      3
# 7937  ...      181.0  machine learning engineer         na      4785      3
# 7967  ...      181.0  machine learning engineer         na      4785      3
# 7997  ...      181.0  machine learning engineer         na      4785      3
#
#      techs education               company_name         job_state  age
# 13       0         0                   McKinney       New York-NY   54
# 28       0         0              SmarterTravel  Massachusetts-MA   25
# 54       0         0            Dermalogica LLC     California-CA   37
# 193      0         0              SmarterTravel  Massachusetts-MA   25
# 198      0         0            Dermalogica LLC     California-CA   37
# ...    ...       ...                        ...               ...  ...
# 7877     0         0  Toyota Research Institute     California-CA    7
# 7907     0         0  Toyota Research Institute     California-CA    7
# 7937     0         0  Toyota Research Institute     California-CA    7
# 7967     0         0  Toyota Research Institute     California-CA    7
# 7997     0         0  Toyota Research Institute     California-CA    7
#
# [279 rows x 24 columns]

# %%
 raw_df.loc[raw_df['Type of ownership'] == 'Subsidiary or Business Segment', 'Type of ownership'] = 'Company - Private'

# %%
raw_df['Type of ownership'].value_counts()
# Out:
# Company - Private           2836
# Company - Public            2187
# -1                           375
# Nonprofit Organization       240
# Self-employed                105
# Government                    62
# Private Practice / Firm       39
# College / University          29
# School / School District      13
# Hospital                       6
# Name: Type of ownership, dtype: int64

# %%
raw_df[raw_df['Type of ownership'] == -1]
# Out:
#                                               Job Title  \
# 26                                         Data Analyst
# 36                                      Tableau Analyst
# 41                                         Data Analyst
# 42                                     Business Analyst
# 71                                  Junior Data Analyst
# ...                                                 ...
# 7339  Research Scientist: Machine Learning & AI (Rem...
# 7377  Research Scientist: Machine Learning & AI (Rem...
# 7384  Principal Machine Learning Engineers (Remote/P...
# 7398  Research Scientist: Machine Learning & AI (Rem...
# 7413  Principal Machine Learning Engineers (Remote/P...
#
#                                         Salary Estimate  \
# 26                Employer Provided Salary:$70K - $120K
# 36    Employer Provided Salary:$45.00 - $50.00 Per Hour
# 41             Employer Provided Salary:$40.00 Per Hour
# 42                 Employer Provided Salary:$40K - $64K
# 71                        Employer Provided Salary:$70K
# ...                                                 ...
# 7339  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7377  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7384  Employer Provided Salary:$65.00 - $120.00 Per ...
# 7398  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7413  Employer Provided Salary:$65.00 - $120.00 Per ...
#
#                                         Job Description  Rating  \
# 26    Title : Data Analyst / Data Engineer\nLocation...    -1.0
# 36    Locations: Remote with few days in a month in ...     4.0
# 41    Complete Description:\nThe District of Columbi...    -1.0
# 42    We are a leading job agency seeking a Business...    -1.0
# 71    Position Summary:\nPosition Description: Junio...     4.0
# ...                                                 ...     ...
# 7339  This is a part-time and remote job for Researc...    -1.0
# 7377  This is a part-time and remote job for Researc...    -1.0
# 7384  This is a part-time and remote job for Princip...    -1.0
# 7398  This is a part-time and remote job for Researc...    -1.0
# 7413  This is a part-time and remote job for Princip...    -1.0
#
#                                            Company Name        Location  \
# 26                                             AKT Corp          Remote
# 36                             IndoMinds Solutions\n4.0          Remote
# 41                                         gointellects  Washington, DC
# 42                                       Upen Group Inc      Irving, TX
# 71                         Sancorp Consulting, LLC\n4.0   Arlington, VA
# ...                                                 ...             ...
# 7339  AI Labs at the American Alliance for Internati...          Remote
# 7377  AI Labs at the American Alliance for Internati...          Remote
# 7384  AI Labs at the American Alliance for Internati...          Remote
# 7398  AI Labs at the American Alliance for Internati...          Remote
# 7413  AI Labs at the American Alliance for Internati...          Remote
#
#                    Size  Founded Type of ownership  \
# 26                   -1       -1                -1
# 36    1 to 50 Employees       -1                -1
# 41                   -1       -1                -1
# 42                   -1       -1                -1
# 71    1 to 50 Employees       -1                -1
# ...                 ...      ...               ...
# 7339                 -1       -1                -1
# 7377                 -1       -1                -1
# 7384                 -1       -1                -1
# 7398                 -1       -1                -1
# 7413                 -1       -1                -1
#
#                                      Industry  ... avg_salary  \
# 26                                         -1  ...       95.0
# 36                                         -1  ...       85.5
# 41                                         -1  ...       72.0
# 42                                         -1  ...       52.0
# 71    Enterprise Software & Network Solutions  ...       70.0
# ...                                       ...  ...        ...
# 7339                                       -1  ...      171.0
# 7377                                       -1  ...      171.0
# 7384                                       -1  ...      166.5
# 7398                                       -1  ...      171.0
# 7413                                       -1  ...      166.5
#
#                       job_title  seniority  desc_len  tools techs education  \
# 26                 data analyst         na       415      1     0         0
# 36                 data analyst         na       368      1     0         0
# 41                 data analyst         na      1166      1     0         0
# 42                 data analyst         na       582      1     0         0
# 71                 data analyst     junior       248      1     0         0
# ...                         ...        ...       ...    ...   ...       ...
# 7339  machine learning engineer         na      2764      2    15         6
# 7377  machine learning engineer         na      2764      2    15         6
# 7384  machine learning engineer     senior      2600      2    15         6
# 7398  machine learning engineer         na      2764      2    15         6
# 7413  machine learning engineer     senior      2600      2    15         6
#
#                                            company_name  \
# 26                                             AKT Corp
# 36                                  IndoMinds Solutions
# 41                                         gointellects
# 42                                       Upen Group Inc
# 71                              Sancorp Consulting, LLC
# ...                                                 ...
# 7339  AI Labs at the American Alliance for Internati...
# 7377  AI Labs at the American Alliance for Internati...
# 7384  AI Labs at the American Alliance for Internati...
# 7398  AI Labs at the American Alliance for Internati...
# 7413  AI Labs at the American Alliance for Internati...
#
#                     job_state  age
# 26                     Remote   -1
# 36                     Remote   -1
# 41    District of Columbia-DC   -1
# 42                   Texas-TX   -1
# 71                Virginia-VA   -1
# ...                       ...  ...
# 7339                   Remote   -1
# 7377                   Remote   -1
# 7384                   Remote   -1
# 7398                   Remote   -1
# 7413                   Remote   -1
#
# [375 rows x 24 columns]

# %% [markdown]
# ## 10. Industry Column

# %%
raw_df['Industry'].value_counts()
# Out:
# -1                                         813
# Internet & Web Services                    654
# Information Technology Support Services    563
# Computer Hardware Development              485
# Health Care Services & Hospitals           408
#                                           ...
# Cable, Internet & Telephone Providers        1
# Convenience Stores                           1
# Culture & Entertainment                      1
# Broadcast Media                              1
# Beauty & Personal Accessories Stores         1
# Name: Industry, Length: 70, dtype: int64

# %%
raw_df.loc[raw_df['Industry'] == '-1', 'company_name'].value_counts().head(10)
# Out:
# Cognize Tech Solutions                                          29
# AI Labs at the American Alliance for International Education    29
# PROC9                                                           29
# Juji                                                            29
# DSMH LLC                                                        27
# Decision Point Healthcare                                       25
# I20 Technologies                                                24
# Kommforcesolutions                                              24
# Konnectingtree                                                  23
# Alliance International CHB, Inc.                                22
# Name: company_name, dtype: int64

# %%
raw_df.loc[raw_df['company_name'] == 'Juji', 'Industry'] = 'Information Technology Support Services'

# %%
raw_df.loc[raw_df['company_name'] == 'Konnectingtree', 'Industry'] = 'Information Technology Support Services'

# %%
raw_df.loc[raw_df['Industry'] == '-1', 'company_name'].value_counts()
# Out:
# Cognize Tech Solutions                                          29
# AI Labs at the American Alliance for International Education    29
# PROC9                                                           29
# DSMH LLC                                                        27
# Decision Point Healthcare                                       25
#                                                                 ..
# Nexlogica                                                        1
# Synapseb systems                                                 1
# Aunalytics                                                       1
# Cloud and Things Inc                                             1
# MDACCESS                                                         1
# Name: company_name, Length: 121, dtype: int64

# %%
len(raw_df.loc[raw_df['Industry'] == '-1', 'company_name'])
# Out:
# 724

# %% [markdown]
# ## 11. Sector Column

# %%
raw_df['Sector'].value_counts()
# Out:
# Information Technology                         2121
# -1                                              776
# Healthcare                                      421
# Financial Services                              322
# Media & Communication                           299
# Retail & Wholesale                              281
# Manufacturing                                   252
# Insurance                                       239
# Management & Consulting                         223
# Pharmaceutical & Biotechnology                  172
# Transportation & Logistics                      128
# Energy, Mining & Utilities                       95
# Education                                        84
# Government & Public Administration               73
# Nonprofit & NGO                                  69
# Construction, Repair & Maintenance Services      66
# Aerospace & Defense                              49
# Human Resources & Staffing                       34
# Agriculture                                      32
# Legal                                            31
# Telecommunications                               20
# Hotels & Travel Accommodation                    17
# Arts, Entertainment & Recreation                 15
# Personal Consumer Services                       13
# Restaurants & Food Service                       11
# Real Estate                                      11
# Name: Sector, dtype: int64

# %%
raw_df.loc[raw_df['Sector'] == '-1', 'company_name'].value_counts()
# Out:
# Cognize Tech Solutions                                          29
# AI Labs at the American Alliance for International Education    29
# PROC9                                                           29
# Juji                                                            29
# DSMH LLC                                                        27
#                                                                 ..
# Eagle Outsourcing Pte ltd                                        1
# IVID TEK INC                                                     1
# Nexlogica                                                        1
# Synapseb systems                                                 1
# MDACCESS                                                         1
# Name: company_name, Length: 123, dtype: int64

# %%
raw_df.loc[raw_df['company_name'] == 'Juji' , 'Sector'] = 'Information Technology'

# %%
raw_df.loc[raw_df['company_name'] == 'Konnectingtree' , 'Sector'] = 'Information Technology'

# %%
raw_df.loc[raw_df['Sector'] == '-1', 'company_name'].value_counts()
# Out:
# Cognize Tech Solutions                                          29
# AI Labs at the American Alliance for International Education    29
# PROC9                                                           29
# DSMH LLC                                                        27
# Decision Point Healthcare                                       25
#                                                                 ..
# Nexlogica                                                        1
# Synapseb systems                                                 1
# Aunalytics                                                       1
# Cloud and Things Inc                                             1
# MDACCESS                                                         1
# Name: company_name, Length: 121, dtype: int64

# %%
len(raw_df.loc[raw_df['Sector'] == '-1', 'company_name'].value_counts())
# Out:
# 121

# %% [markdown]
# ## 12. Revenue Column

# %%
raw_df['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable            2289
# $10+ billion (USD)                  1226
# $1 to $5 billion (USD)               610
# $25 to $100 million (USD)            359
# -1                                   323
# $100 to $500 million (USD)           262
# $5 to $25 million (USD)              235
# $5 to $10 billion (USD)              164
# $500 million to $1 billion (USD)     152
# $1 to $5 million (USD)               149
# Less than $1 million (USD)            85
# Name: Revenue, dtype: int64

# %%
raw_df[raw_df['Revenue'] == '-1']
# Out:
#                                               Job Title  \
# 26                                         Data Analyst
# 41                                         Data Analyst
# 42                                     Business Analyst
# 80                                     Business Analyst
# 110                   Junior Data Analyst (Entry Level)
# ...                                                 ...
# 7339  Research Scientist: Machine Learning & AI (Rem...
# 7377  Research Scientist: Machine Learning & AI (Rem...
# 7384  Principal Machine Learning Engineers (Remote/P...
# 7398  Research Scientist: Machine Learning & AI (Rem...
# 7413  Principal Machine Learning Engineers (Remote/P...
#
#                                         Salary Estimate  \
# 26                Employer Provided Salary:$70K - $120K
# 41             Employer Provided Salary:$40.00 Per Hour
# 42                 Employer Provided Salary:$40K - $64K
# 80                 Employer Provided Salary:$40K - $64K
# 110                       Employer Provided Salary:$55K
# ...                                                 ...
# 7339  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7377  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7384  Employer Provided Salary:$65.00 - $120.00 Per ...
# 7398  Employer Provided Salary:$70.00 - $120.00 Per ...
# 7413  Employer Provided Salary:$65.00 - $120.00 Per ...
#
#                                         Job Description  Rating  \
# 26    Title : Data Analyst / Data Engineer\nLocation...    -1.0
# 41    Complete Description:\nThe District of Columbi...    -1.0
# 42    We are a leading job agency seeking a Business...    -1.0
# 80    We are a leading job agency seeking a Business...    -1.0
# 110   This is NOT a remote position.\nJoin the best ...    -1.0
# ...                                                 ...     ...
# 7339  This is a part-time and remote job for Researc...    -1.0
# 7377  This is a part-time and remote job for Researc...    -1.0
# 7384  This is a part-time and remote job for Princip...    -1.0
# 7398  This is a part-time and remote job for Researc...    -1.0
# 7413  This is a part-time and remote job for Princip...    -1.0
#
#                                            Company Name              Location  \
# 26                                             AKT Corp                Remote
# 41                                         gointellects        Washington, DC
# 42                                       Upen Group Inc            Irving, TX
# 80                                       Upen Group Inc            Irving, TX
# 110                    Alliance International CHB, Inc.  Saint Petersburg, FL
# ...                                                 ...                   ...
# 7339  AI Labs at the American Alliance for Internati...                Remote
# 7377  AI Labs at the American Alliance for Internati...                Remote
# 7384  AI Labs at the American Alliance for Internati...                Remote
# 7398  AI Labs at the American Alliance for Internati...                Remote
# 7413  AI Labs at the American Alliance for Internati...                Remote
#
#      Size  Founded Type of ownership Industry  ... avg_salary  \
# 26     -1       -1                -1       -1  ...       95.0
# 41     -1       -1                -1       -1  ...       72.0
# 42     -1       -1                -1       -1  ...       52.0
# 80     -1       -1                -1       -1  ...       52.0
# 110    -1       -1                -1       -1  ...       55.0
# ...   ...      ...               ...      ...  ...        ...
# 7339   -1       -1                -1       -1  ...      171.0
# 7377   -1       -1                -1       -1  ...      171.0
# 7384   -1       -1                -1       -1  ...      166.5
# 7398   -1       -1                -1       -1  ...      171.0
# 7413   -1       -1                -1       -1  ...      166.5
#
#                       job_title  seniority  desc_len  tools techs education  \
# 26                 data analyst         na       415      1     0         0
# 41                 data analyst         na      1166      1     0         0
# 42                 data analyst         na       582      1     0         0
# 80                 data analyst         na       582      1     0         0
# 110                data analyst     junior       771      1     0         0
# ...                         ...        ...       ...    ...   ...       ...
# 7339  machine learning engineer         na      2764      2    15         6
# 7377  machine learning engineer         na      2764      2    15         6
# 7384  machine learning engineer     senior      2600      2    15         6
# 7398  machine learning engineer         na      2764      2    15         6
# 7413  machine learning engineer     senior      2600      2    15         6
#
#                                            company_name  \
# 26                                             AKT Corp
# 41                                         gointellects
# 42                                       Upen Group Inc
# 80                                       Upen Group Inc
# 110                    Alliance International CHB, Inc.
# ...                                                 ...
# 7339  AI Labs at the American Alliance for Internati...
# 7377  AI Labs at the American Alliance for Internati...
# 7384  AI Labs at the American Alliance for Internati...
# 7398  AI Labs at the American Alliance for Internati...
# 7413  AI Labs at the American Alliance for Internati...
#
#                     job_state  age
# 26                     Remote   -1
# 41    District of Columbia-DC   -1
# 42                   Texas-TX   -1
# 80                   Texas-TX   -1
# 110                Florida-FL   -1
# ...                       ...  ...
# 7339                   Remote   -1
# 7377                   Remote   -1
# 7384                   Remote   -1
# 7398                   Remote   -1
# 7413                   Remote   -1
#
# [323 rows x 24 columns]

# %%
raw_df.loc[raw_df['Revenue'] == 'Unknown / Non-Applicable', 'company_name'].value_counts()
# Out:
# Realtor.com Careers    128
# Honor                   93
# Mastercard              63
# Runway AI               61
# Visionary Homes         56
#                       ...
# Everside Health          1
# Altak Group              1
# RevOpsforce              1
# Keyrus USA               1
# Zenith                   1
# Name: company_name, Length: 242, dtype: int64

# %% [markdown]
# #### since Revenue is an important column and there is 375 missing values in the Revenus column , i will try to manually fix most of the unknowns values

# %%
# Realtor.com Careers revenue is $446.7 Million
raw_df.loc[raw_df['company_name'] == 'Realtor.com Careers', 'Revenue'] = '$100 to $500 million (USD)'

# %%
# cedar revenue is $117.2 Million
raw_df.loc[raw_df['company_name'] == 'Cedar Inc', 'Revenue'] = '$100 to $500 million (USD)'

# %%
# Mastercard revenue is 22.4 billion
raw_df.loc[raw_df['company_name'] == 'Mastercard', 'Revenue'] = '$10+ billion (USD)'

# %%
# Octaura revenue is < 5 million
raw_df.loc[raw_df['company_name'] == 'Octaura', 'Revenue'] = '$1 to $5 million (USD)'

# %%
# Veracity Software revenue is < 5 million
raw_df.loc[raw_df['company_name'] == 'Veracity Software', 'Revenue'] = '$1 to $5 million (USD)'

# %%
# Notion  revenue is 67.2 million
raw_df.loc[raw_df['company_name'] == 'Notion', 'Revenue'] = '$25 to $100 million (USD)'

# %%
# current  revenue is 70  million
raw_df.loc[raw_df['company_name'] == 'current', 'Revenue'] = '$25 to $100 million (USD)'

# %%
# National Security Agency  revenue is 7.7 billion
raw_df.loc[raw_df['company_name'] == 'National Security Agency', 'Revenue'] = '$5 to $10 billion (USD)'

# %%
# Dataminr revenue is 168 milion
raw_df.loc[raw_df['company_name'] == 'Dataminr', 'Revenue'] = '$100 to $500 million (USD)'

# %%
# FAST GROWING TREES LLC  revenue is 20 milion
raw_df.loc[raw_df['company_name'] == 'FAST GROWING TREES LLC', 'Revenue'] = '$5 to $25 million (USD)'

# %%
# Tencent  revenue is 80 bilion
raw_df.loc[raw_df['company_name'] == 'Tencent', 'Revenue'] = '$10+ billion (USD)'

# %%
# Tencent  revenue is 80 bilion
raw_df.loc[raw_df['company_name'] == 'Tencent', 'Revenue'] = '$10+ billion (USD)'

# %%
# Konnectingtree  revenue is < 5 milion
raw_df.loc[raw_df['company_name'] == 'Konnectingtree', 'Revenue'] = '$1 to $5 million (USD)'

# %%
# Cadent  revenue is <  1.4 milion
raw_df.loc[raw_df['company_name'] == 'Cadent', 'Revenue'] = '$5 to $25 million (USD)'

# %%
# Hyperspace Ventures  revenue is < 5 milion
raw_df.loc[raw_df['company_name'] == 'Hyperspace Ventures', 'Revenue'] = '$1 to $5 million (USD)'

# %%
# University of Minnesota  revenue is 3.9 bilion
raw_df.loc[raw_df['company_name'] == 'University of Minnesota', 'Revenue'] = '$1 to $5 billion (USD)'

# %%
raw_df.loc[raw_df['Revenue'] == 'Unknown / Non-Applicable', 'company_name'].value_counts()
# Out:
# Honor                            93
# Runway AI                        61
# Visionary Homes                  56
# US Acute Care Solutions          46
# TikTok                           39
#                                  ..
# iSpot.tv                          1
# WA River Protection Solutions     1
# Alt Shift USA                     1
# Attentive Mobile                  1
# Aunalytics                        1
# Name: company_name, Length: 227, dtype: int64

# %%
len(raw_df.loc[raw_df['Revenue'] == 'Unknown / Non-Applicable'])
# Out:
# 1814

# %%
# change all unknowns to -1
raw_df.loc[raw_df['Revenue'] == 'Unknown / Non-Applicable', 'Revenue']= '-1'

# %%
raw_df['Revenue'].value_counts()
# Out:
# -1                                  2137
# $10+ billion (USD)                  1299
# $1 to $5 billion (USD)               614
# $100 to $500 million (USD)           461
# $25 to $100 million (USD)            410
# $5 to $25 million (USD)              271
# $1 to $5 million (USD)               240
# $5 to $10 billion (USD)              185
# $500 million to $1 billion (USD)     152
# Less than $1 million (USD)            85
# Name: Revenue, dtype: int64

# %% [markdown]
# ## Data Cleaning and Preprocessing Notes

# %% [markdown]
# ### 1. Job Title column ✔️
#     a. classify the job titles in terms of title and seniority ✔️
#     b. Fixed the decision scientist bug ✔️
#     b. the seniority column has alot of missing values , maybe figure out how to deal with this later or drop it 🛠
# ### 2. SalaryColumn ✔️
#     a. Remove rows in which salary equal -1 ✔️
#     b. Remove any Text in the columns  ✔️
#     c. Change Hourly rate salaries to Yearly rat ✔️
#     d. Create Three new columns min, max, avg salary✔️
# ### 3.Job Description Column ✔️
#     a. Create a desc_length column contains the length of characters in the job Description, to see if their a correlation between the job description length and salary ✔️
#     b. maybe we try to preprocess the descriptions, try to get new insights ✔️
# ### 4. Rating Column
#     a. Deal with missing Rating values(-1) 🛠
# ### 5. Company Name Column ✔️
#     a. Remove the rating in the company name tail ✔️
#     b. Remove the '\n' text in the company name tail ✔️
# ### 6. Company Location Column✔️
#     a. remove the city name and keep the state abbreviation only✔️
#     b. added the state name beside its abbreviation for clarity ✔️
#     b. deal with the anomalies['texas', 'newyork state', 'united states'] ✔️
# ### 7. Company Size Column
#     a. Deal with most of missing values in the size Column ✔️
#     b. maybe change this column to categories 🛠
#     c. what will we do with the remaining  missing values 🛠
# ### 8.Founded column
#     a. change the Founded year to how old the company is ✔️
#     b. deal with the missing values ✔️
#     c. how are gonna deal with the remaining  missing values 🛠
#     c. maybe we need to turn this column into categories of age 🛠
# ### 9. Type of ownership column
#     a. Convert subsidiary or busniess segment to company private✔️
#     b. convert all missing values to -1✔️
#     c. deal with missing values and turn into categories🛠
# ### 10. Industry Column
#     a. changed Juji and Konnecting Tree values from -1 to it support services✔️
#     b. deal with the remaining missing values🛠
# ### 11. Sector Column
#     a. changed Juji and Konnecting Tree values from -1 to it support services✔️
#     b. deal with the remaining missing values🛠
# ### 12.Revenue Column
#     a. since Revenue is an important column and there is 375 missing values in the Revenus column , i will try to manually fix most of the unknowns values✔️
#     b. deal with the missing values in revenue column🛠

# %% [markdown]
# ## Export Data to a CSV File and a Pickle File

# %%
raw_df.head()
# Out:
#                            Job Title  \
# 2                       Data Analyst
# 3                Data Mining Analyst
# 4                       Data Analyst
# 5                       Data Analyst
# 6  Data Warehouse Programmer analyst
#
#                                      Salary Estimate  \
# 2                       $54K - $82K (Glassdoor est.)
# 3                       $63K - $91K (Glassdoor est.)
# 4  Employer Provided Salary:$40.00 - $45.00 Per Hour
# 5               Employer Provided Salary:$65K - $85K
# 6                      Employer Provided Salary:$99K
#
#                                      Job Description  Rating  \
# 2  This is an in-office position, working out of ...     4.5
# 3  Kodak Alaris is a global technology company th...     4.0
# 4  Primary Duties: Data Analyst 2\nProvide ad-hoc...     3.9
# 5   Responsible for the design, development and ...     2.0
# 6  Overview:\nData Warehouse Programmer Analyst\n...     4.0
#
#                                 Company Name         Location  \
# 2                       Visionary Homes\n4.5  North Logan, UT
# 3                          Kodak Alaris\n4.0    Rochester, NY
# 4                     GSK Solutions Inc\n3.9     Richmond, VA
# 5                Cognize Tech Solutions\n2.0           Remote
# 6  Partnership HealthPlan of California\n4.0    Fairfield, CA
#
#                      Size  Founded       Type of ownership  \
# 2     51 to 200 Employees     2004       Company - Private
# 3  1001 to 5000 Employees     2013       Company - Private
# 4       1 to 50 Employees     2010       Company - Private
# 5     51 to 200 Employees       -1       Company - Private
# 6   501 to 1000 Employees     1994  Nonprofit Organization
#
#                                   Industry  ... avg_salary     job_title  \
# 2                             Construction  ...       68.0  data analyst
# 3  Information Technology Support Services  ...       77.0  data analyst
# 4                      Business Consulting  ...       76.5  data analyst
# 5                                       -1  ...       75.0  data analyst
# 6         Health Care Services & Hospitals  ...       99.0  data analyst
#
#    seniority  desc_len  tools techs education  \
# 2         na       914      1     0         0
# 3         na      2071      2     0         0
# 4         na       593      1     0         0
# 5         na       901      1     0         0
# 6         na       744      1     0         0
#
#                            company_name      job_state  age
# 2                       Visionary Homes        Utah-UT   19
# 3                          Kodak Alaris    New York-NY   10
# 4                     GSK Solutions Inc    Virginia-VA   13
# 5                Cognize Tech Solutions         Remote   -1
# 6  Partnership HealthPlan of California  California-CA   29
#
# [5 rows x 24 columns]

# %%
raw_df=raw_df.dropna()

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5663 entries, 2 to 7999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5663 non-null   object
#  1   Salary Estimate    5663 non-null   object
#  2   Job Description    5663 non-null   object
#  3   Rating             5663 non-null   float64
#  4   Company Name       5663 non-null   object
#  5   Location           5663 non-null   object
#  6   Size               5663 non-null   object
#  7   Founded            5663 non-null   int64
#  8   Type of ownership  5663 non-null   object
#  9   Industry           5663 non-null   object
#  10  Sector             5663 non-null   object
#  11  Revenue            5663 non-null   object
#  12  min_salary         5663 non-null   int64
#  13  max_salary         5663 non-null   int64
#  14  avg_salary         5663 non-null   float64
#  15  job_title          5663 non-null   object
#  16  seniority          5663 non-null   object
#  17  desc_len           5663 non-null   int64
#  18  tools              5663 non-null   int64
#  19  techs              5663 non-null   int64
#  20  education          5663 non-null   int64
#  21  company_name       5663 non-null   object
#  22  job_state          5663 non-null   object
#  23  age                5663 non-null   int64
# dtypes: float64(2), int64(8), object(14)
# memory usage: 1.1+ MB

# %%
raw_df.to_csv(CSV_EXPORT_PATH, index = False)

# %%
raw_df.to_pickle(PKL_EXPORT_PATH)
